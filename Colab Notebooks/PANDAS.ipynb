# %%
import pandas as pd

d = pd.read_csv('data.csv')
# print(d)
# print(d.columns)
print(d.head(5))
print(d.tail(5))
print(d.info())
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# ...

# %% [markdown]
# You can upload your files to the Colab environment using the file upload feature in the left sidebar or by using code like this:

# %%
a = d["Administration"]
b = d[["Administration"]]
print(type(a))
print(type(b))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
x = d.iloc[-1]
print(x.head())
x = d.iloc[1:-1]
print(x.head())
# Out:
# R&D Spend                 0.0
# Administration       116983.8
# Marketing Spend      45173.06
# State              California
# Profit                14681.4
# Name: 49, dtype: object
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12

# %%
x = d.Administration
print(x.head())
# Out:
# 0    136897.80
# 1    151377.59
# 2    101145.55
# 3    118671.85
# 4     91391.77
# Name: Administration, dtype: float64

# %%
x = d[(d["R&D Spend"] >= 110000) & (d["R&D Spend"] < 150000)]
print(x.head(50))
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04

# %%
x = d.sort_values(by = ["Marketing Spend", "State"], ascending = [True, False])
print(x)
# print(d)
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
x = d.sort_values(by = ["Marketing Spend", "State"], ascending = [True, False], inplace = True)
print(x)
print(d)
# Out:
# None
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 19   86419.70       153514.11             0.00    New York  122776.86
# 48     542.05        51743.15             0.00    New York   35673.41
# 47       0.00       135426.92             0.00  California   42559.73
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 44   22177.74       154806.14         28334.72  California   65200.33
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 49       0.00       116983.80         45173.06  California   14681.40
# 32   63408.86       129219.61         46085.25  California   97427.84
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# ...

# %%
x = d.groupby("State")["Profit"].sum()
print(x)
# Out:
# State
# California    1766387.98
# Florida       1900384.39
# New York      1933859.59
# Name: Profit, dtype: float64

# %%
d['New'] = d['Marketing Spend'] + d['Administration']
print(d)
d.drop('New', axis = 1, inplace = True)
print(d)
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 19   86419.70       153514.11             0.00    New York  122776.86
# 48     542.05        51743.15             0.00    New York   35673.41
# 47       0.00       135426.92             0.00  California   42559.73
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 44   22177.74       154806.14         28334.72  California   65200.33
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 49       0.00       116983.80         45173.06  California   14681.40
# 32   63408.86       129219.61         46085.25  California   97427.84
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# ...

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [12, 8, 12, 8, 12]
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Graph")
plt.plot(x, y, "g", linewidth = "3", marker = "*")
plt.show()

# %%
import numpy as np

# x = [1, 2, 3, 4, 5, 6]
y = [12, 8, 12, 8, 12, 80]
x = np.arange(1, 7)
ms = [10, 20, 30, 40, 50, 60]
plt.xlabel("Months")
plt.ylabel("Sales")
plt.title("Data")
plt.bar(x, y, color = ['b', 'r', 'g', 'k', 'b', 'r'], width = 0.25)
plt.bar(x+0.25, ms, width = 0.25, color = 'y')
plt.show()
